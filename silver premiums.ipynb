# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import os
import re
from datetime import date
import time 

# ignore SettingWithCopyWarning:
pd.options.mode.chained_assignment = None

# %%
# create folder for the HTMLs
folder_html = 'Gold_de'
if not os.path.exists(folder_html):
    os.makedirs(folder_html)

# %%
# create folder for the csvs
folder_csv = 'Gold_de_csv'
if not os.path.exists(folder_csv):
    os.makedirs(folder_csv)

# %%
date_today = date.today()

# %%
file_name = 'gold_de_'
end_html = '.html'
end_csv = '.csv'

# %%
file_name + date_today.strftime('%d.%m.%Y') + end_html
# Out:
# 'gold_de_13.05.2020.html'

# %%
# get the html with request
# save the html in the folder
url = 'https://www.gold.de/aufgeldtabelle/silber/'
r = requests.get(url)
with open(os.path.join(folder_html, file_name + date_today.strftime('%d.%m.%Y') + end_html), mode = 'w') as file:
    file.write(r.text)

# %%
path_html = folder_html + '/' + file_name + date_today.strftime('%d.%m.%Y') + end_html

# %%
df_list = pd.read_html(path_html)

# %%
df_list[0]
# Out:
#         0         1         2        3         4
# 0     NaN  USD / oz  EUR / oz  EUR / g  EUR / kg
# 1    GOLD   1.70798   1.57043     5049  50.49037
# 2  SILBER      1554      1429      046     45939

# %%
df_list[1]
# Out:
#                                                   Rang  \
# 0    Produkte: Münzen Barren Münzbarren, TafelnBudg...
# 1                                                    1
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 248                                                246
# 249                                                247
# 250                                                248
# 251                                                249
# 252                                                250
#
#                                     Produktbezeichnung  \
# 0    Produkte: Münzen Barren Münzbarren, TafelnBudg...
# 1              Silberbarren 1000 ozGold & Silver World
# 2                      Silberbarren 1 kgcoininvest.com
# 3                        Münzbarren 5 kgMP Edelmetalle
# 4                      Maple Leaf 1 ozSilber-Corner.de
# ..                                                 ...
# 248                           Schwan 5 ozAuragentum.de
# 249  Comic, Kino & TV (Silber) 19,98 gmuenzdiscount.de
# 250  Evolution - Wonderful World 1 ozGeiger Edelmet...
# 251                      Niue Lunar Serie 5 ozMünzland
# 252              Morgan Dollar 24,05 gmuenzdiscount.de
#
#                                           Produktpreis  \
# 0    Produkte: Münzen Barren Münzbarren, TafelnBudg...
# 1                                        17.011,84 EUR
# 2                                           625,11 EUR
# 3                                         3.156,13 EUR
# 4                                            19,65 EUR
# ..                                                 ...
# 248                                         349,00 EUR
# 249                                          44,90 EUR
# 250                                          70,00 EUR
# 251                                         355,00 EUR
# 252                                          55,00 EUR
#
#                     Preis/kg                Preis/oz               Preis/g  \
# 0    Silberspot/kg459,39 EUR  Silberspot/oz14,29 EUR  Silberspot/g0,46 EUR
# 1                 607,60 EUR               18,90 EUR              0,61 EUR
# 2                 625,10 EUR               19,44 EUR              0,63 EUR
# 3                 631,20 EUR               19,63 EUR              0,63 EUR
# 4                 631,80 EUR               19,65 EUR              0,63 EUR
# ..                       ...                     ...                   ...
# 248             2.244,20 EUR               69,80 EUR              2,24 EUR
# 249             2.247,20 EUR               69,90 EUR              2,25 EUR
# 250             2.250,60 EUR               70,00 EUR              2,25 EUR
# 251             2.282,70 EUR               71,00 EUR              2,28 EUR
# 252             2.286,90 EUR               71,13 EUR              2,29 EUR
#
#     Aufgeld in % Aufgeld in %.1  Unnamed: 8
# 0            NaN            NaN         NaN
# 1        32,26 %            NaN         NaN
# 2        36,07 %            NaN         NaN
# 3        37,40 %            NaN         NaN
# 4        37,53 %            NaN         NaN
# ..           ...            ...         ...
# 248     388,52 %            NaN         NaN
# 249     389,17 %            NaN         NaN
# 250     389,91 %            NaN         NaN
# 251     396,90 %            NaN         NaN
# 252     397,82 %            NaN         NaN
#
# [253 rows x 9 columns]

# %%
df = df_list[1]

# %% [markdown]
# ### Cleaning steps

# %%
df = df.iloc[1:]

# %%
df.dropna(axis = 1, how = 'all', inplace = True)

# %%
df.dropna(axis = 0, how = 'all', inplace = True)

# %%
# drop unrelevant columns
if 'Aufgeld in %.1' in df.columns.values:
    df.drop(columns = 'Aufgeld in %.1', inplace = True)

# %%
df
# Out:
#     Rang                                 Produktbezeichnung   Produktpreis  \
# 1      1            Silberbarren 1000 ozGold & Silver World  17.011,84 EUR
# 2      2                    Silberbarren 1 kgcoininvest.com     625,11 EUR
# 3      3                      Münzbarren 5 kgMP Edelmetalle   3.156,13 EUR
# 4      4                    Maple Leaf 1 ozSilber-Corner.de      19,65 EUR
# 5      5                    Eule von Athen 1 ozMünzen Engel      19,72 EUR
# ..   ...                                                ...            ...
# 248  246                           Schwan 5 ozAuragentum.de     349,00 EUR
# 249  247  Comic, Kino & TV (Silber) 19,98 gmuenzdiscount.de      44,90 EUR
# 250  248  Evolution - Wonderful World 1 ozGeiger Edelmet...      70,00 EUR
# 251  249                      Niue Lunar Serie 5 ozMünzland     355,00 EUR
# 252  250              Morgan Dollar 24,05 gmuenzdiscount.de      55,00 EUR
#
#          Preis/kg   Preis/oz   Preis/g Aufgeld in %
# 1      607,60 EUR  18,90 EUR  0,61 EUR      32,26 %
# 2      625,10 EUR  19,44 EUR  0,63 EUR      36,07 %
# 3      631,20 EUR  19,63 EUR  0,63 EUR      37,40 %
# 4      631,80 EUR  19,65 EUR  0,63 EUR      37,53 %
# 5      634,00 EUR  19,72 EUR  0,63 EUR      38,01 %
# ..            ...        ...       ...          ...
# 248  2.244,20 EUR  69,80 EUR  2,24 EUR     388,52 %
# 249  2.247,20 EUR  69,90 EUR  2,25 EUR     389,17 %
# 250  2.250,60 EUR  70,00 EUR  2,25 EUR     389,91 %
# 251  2.282,70 EUR  71,00 EUR  2,28 EUR     396,90 %
# 252  2.286,90 EUR  71,13 EUR  2,29 EUR     397,82 %
#
# [251 rows x 7 columns]

# %%
df.drop(index = df[df['Rang']=="Gesamte Aufgeldtabelle anzeigen"].index.values, inplace = True)

# %%
df.rename(columns = {'Produktbezeichnung':'Product', 'Produktpreis':'Price in EUR', 'Preis/kg':'Price/kg', 
                     'Preis/oz':'Price/oz', 'Preis/g':'Price/g', 'Aufgeld in %':'Premiums in %'}, 
         inplace = True)

# %%
df['Price in EUR'] = df['Price in EUR'].map(lambda x: str(x).replace('EUR', '').strip().replace('.', '').replace(',','.'))
df['Price/kg'] = df['Price/kg'].map(lambda x: str(x).replace('EUR', '').strip().replace('.', '').replace(',','.'))
df['Price/oz'] = df['Price/oz'].map(lambda x: str(x).replace('EUR', '').strip().replace('.', '').replace(',','.'))
df['Price/g'] = df['Price/g'].map(lambda x: str(x).replace('EUR', '').strip().replace('.', '').replace(',','.'))
df['Premiums in %'] = df['Premiums in %'].map(lambda x: str(x).replace('%', '').strip().replace('.', '').replace(',','.'))

# %%
df['Price in EUR'] = df['Price in EUR'].astype('float')
df['Price/kg'] = df['Price/kg'].astype('float')
df['Price/oz'] = df['Price/oz'].astype('float')
df['Price/g'] = df['Price/g'].astype('float')
df['Premiums in %'] = df['Premiums in %'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 1 to 252
# Data columns (total 7 columns):
# Rang             250 non-null object
# Product          250 non-null object
# Price in EUR     250 non-null float64
# Price/kg         250 non-null float64
# Price/oz         250 non-null float64
# Price/g          250 non-null float64
# Premiums in %    250 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 15.6+ KB

# %%
path_to_csv = folder_csv + '/' + file_name + date_today.strftime('%d.%m.%Y') + end_csv

# %%
df.to_csv(path_to_csv, index = None)

# %%
df
# Out:
#     Rang                                            Product  Price in EUR  \
# 1      1            Silberbarren 1000 ozGold & Silver World      17011.84
# 2      2                    Silberbarren 1 kgcoininvest.com        625.11
# 3      3                      Münzbarren 5 kgMP Edelmetalle       3156.13
# 4      4                    Maple Leaf 1 ozSilber-Corner.de         19.65
# 5      5                    Eule von Athen 1 ozMünzen Engel         19.72
# ..   ...                                                ...           ...
# 248  246                           Schwan 5 ozAuragentum.de        349.00
# 249  247  Comic, Kino & TV (Silber) 19,98 gmuenzdiscount.de         44.90
# 250  248  Evolution - Wonderful World 1 ozGeiger Edelmet...         70.00
# 251  249                      Niue Lunar Serie 5 ozMünzland        355.00
# 252  250              Morgan Dollar 24,05 gmuenzdiscount.de         55.00
#
#      Price/kg  Price/oz  Price/g  Premiums in %
# 1       607.6     18.90     0.61          32.26
# 2       625.1     19.44     0.63          36.07
# 3       631.2     19.63     0.63          37.40
# 4       631.8     19.65     0.63          37.53
# 5       634.0     19.72     0.63          38.01
# ..        ...       ...      ...            ...
# 248    2244.2     69.80     2.24         388.52
# 249    2247.2     69.90     2.25         389.17
# 250    2250.6     70.00     2.25         389.91
# 251    2282.7     71.00     2.28         396.90
# 252    2286.9     71.13     2.29         397.82
#
# [250 rows x 7 columns]

# %% [markdown]
# ### Extract infos from the Product column

# %%
# use sample function to check which expressions for weight are used
df['Product'].sample(n=20)
# Out:
# 212                   China Panda 1/2 ozLeihhaus Lohmann
# 12                  Lunar Serie III 1 kgSilver-to-go.com
# 210                 Lunar Serie I 1/2 ozLeihhaus Lohmann
# 107                Niue Lunar Serie 1 ozLeihhaus Lohmann
# 84                       Kookaburra 2 ozLeihhaus Lohmann
# 15                        Krügerrand 1 ozAnlagegold24.de
# 39                   Lunar Serie II 1 kgSilber-Corner.de
# 19                                     Koala 1 kgmyVALOR
# 109                             Ruanda 1 ozAuragentum.de
# 60                    America the Beautiful 5 ozMünzland
# 157        Cook Islands 1/4 ozGÖBEL Münzen & Edelmetalle
# 203                Morgan Dollar 24,06 gmuenzdiscount.de
# 216                     Lunar Serie I (RAM) 5 ozMünzland
# 7                       Birds of Prey 1 ozMP Edelmetalle
# 80             Trichternetzspinne 1 ozKleiner Münzhandel
# 46                    Mandala Tschad 1 ozBellmann Münzen
# 108    Ruanda Lunar Serie 1 ozGÖBEL Münzen & Edelmetalle
# 228                        Star Trek 1 ozAnlagegold24.de
# 3                          Münzbarren 5 kgMP Edelmetalle
# 156                        Chiwoo Cheonwang 1 ozMünzland
# Name: Product, dtype: object

# %%
df[['0', '1']] = df['Product'].str.extract(r'(\d|\d{2}|\d{2},\d{2}|\d\/\d|\d{2},\d|\d{3}|\d{4})\s(oz|kg|g|DM)')

# %%
df['Weight'] = df['0'] + ' ' + df['1']

# %%
df.drop(columns= ['0', '1'], inplace = True)

# %%
df['Product_name'] = df['Product'].str.extract(r'([^0-9]+)')

# %%
df['Product_name'] = df['Product_name'].map(lambda x: str(x).strip())

# %%
df.iloc[208]
# Out:
# Rang                                                   209
# Product          Territory of Tokelau 1 ozmuenzdiscount.de
# Price in EUR                                            45
# Price/kg                                            1446.8
# Price/oz                                                45
# Price/g                                               1.45
# Premiums in %                                       214.94
# Weight                                                1 oz
# Product_name                          Territory of Tokelau
# Name: 211, dtype: object

# %%
products_list = df['Product'].to_list()

# %%
page = []
for s in products_list:
    string = str(s).split(r'\d')[-1]
    page.append(string)

# %%
test = 'The Queens Beasts 2 ozMünzen Engel con analagegold24.de'

# %%
test.split(r'(\d|\d{2}|\d{2},\d{2}|\d\/\d|\d{2},\d|\d{3})')
# Out:
# ['The Queens Beasts 2 ozMünzen Engel con analagegold24.de']

# %%
re.split(r'(\d|\d{2}|\d{2},\d{2}|\d\/\d|\d{2},\d|\d{3})\s(oz|kg|g|DM)', test)
# Out:
# ['The Queens Beasts ', '2', 'oz', 'Münzen Engel con analagegold24.de']

# %%
page = []
for i in range(250):
    strings = re.split(r'(\d|\d{2}|\d{2},\d{2}|\d\/\d|\d{2},\d|\d{3})\s(oz|kg|g|DM)', str(products_list[i]))
    page.append(strings)

# %%
page_specific = []
for i in range(250):
    strings = page[i][-1]
    page_specific.append(strings)

# %%
page_specific
# Out:
# ['Gold & Silver World',
#  'coininvest.com',
#  'MP Edelmetalle',
#  'Silber-Corner.de',
#  'Münzen Engel',
#  'Chiemgauer Edelmetallhandel',
#  'MP Edelmetalle',
#  'MP Edelmetalle',
#  'MP Edelmetalle',
#  'MP Edelmetalle',
#  'silber-werte.de',
#  'Silver-to-go.com',
#  'Agosi',
#  'Anlagegold24.de',
#  'Anlagegold24.de',
#  'ESG Edelmetalle',
#  'myVALOR',
#  'Auragentum.de',
#  'myVALOR',
#  ')Heubach Edelmetalle',
#  'ESG Edelmetalle',
#  'Münzen Müller',
#  'silber-werte.de',
#  'heraeus-gold.de',
#  ')Heubach Edelmetalle',
#  ')Agosi',
#  ')MP Edelmetalle',
#  'SGV Ohnheiser',
#  'Aschhoff Edelmetalle',
#  'Heubach Edelmetalle',
#  'silber-werte.de',
#  'Gold & Silver World',
#  'Auragentum.de',
#  'Auragentum.de',
#  'Kronwitter GbR',
#  ')Geiger Edelmetalle',
#  'Silber-Corner.de',
#  'ESG Edelmetalle',
#  ')Heubach Edelmetalle',
#  ')GoldSilberShop.de',
#  'Auragentum.de',
#  'myVALOR',
#  'Faller Edelmetalle',
#  'Bellmann Münzen',
#  'silber-werte.de',
#  'Bellmann Münzen',
#  'Heubach Edelmetalle',
#  'Kronwitter GbR',
#  'Silverbroker.de',
#  'silber-werte.de',
#  'silber-werte.de',
#  'pro aurum',
#  'GÖBEL Münzen & Edelmetalle',
#  'coininvest.com',
#  'Aschhoff Edelmetalle',
#  'silber-werte.de',
#  'Aschhoff Edelmetalle',
#  'Münzland',
#  'Kaiserreich 3 MarkHeubach Edelmetalle',
#  'Goldvorsorge.at',
#  'Faller Edelmetalle',
#  'Leihhaus Lohmann',
#  'Leihhaus Lohmann',
#  ')Leihhaus Lohmann',
#  'Anlagegold24.de',
#  'Bellmann Münzen',
#  'Heubach Edelmetalle',
#  'Münzen Engel',
#  'silber-werte.de',
#  'silber-werte.de',
#  'Faller Edelmetalle',
#  'Goldvorsorge.at',
#  'Heubach Edelmetalle',
#  'Heubach Edelmetalle',
#  'Agosi',
#  'Aschhoff Edelmetalle',
#  'Faller Edelmetalle',
#  'Kleiner Münzhandel',
#  'Münzland',
#  'Aschhoff Edelmetalle',
#  'Münzland',
#  'Leihhaus Lohmann',
#  'Münzland',
#  'silber-werte.de',
#  'Auragentum.de',
#  ')Silverbroker.de',
#  'Anlagegold24.de',
#  'Goldvorsorge.at',
#  'Kronwitter GbR',
#  'Anlagegold24.de',
#  'Münzland',
#  'Leihhaus Lohmann',
#  'Aschhoff Edelmetalle',
#  'philoro Edelmetalle',
#  'Chiemgauer Edelmetallhandel',
#  'GÖBEL Münzen & Edelmetalle',
#  'Faller Edelmetalle',
#  'Faller Edelmetalle',
#  'Münzland',
#  'Gold-Silber-Muenzen-Shop',
#  'philoro Edelmetalle',
#  'MEZEI – Münzen | Edelmetalle',
#  'Argentu.de',
#  'ESG Edelmetalle',
#  'Leihhaus Lohmann',
#  'GÖBEL Münzen & Edelmetalle',
#  'Auragentum.de',
#  'Faller Edelmetalle',
#  ' (5€)Silverbroker.de',
#  'Leihhaus Lohmann',
#  'Silverbroker.de',
#  'Kleiner Münzhandel',
#  'Silverbroker.de',
#  'silber-werte.de',
#  'Heubach Edelmetalle',
#  'Silverbroker.de',
#  'Gold-Silber-Muenzen-Shop',
#  'GoldSilberShop.de',
#  'MP Edelmetalle',
#  'Chiemgauer Edelmetallhandel',
#  'Faller Edelmetalle',
#  'Faller Edelmetalle',
#  'Münzland',
#  'Silverbroker.de',
#  'muenzdiscount.de',
#  ' (10€)Silverbroker.de',
#  'Münzen Engel',
#  'Gold-Silber-Muenzen-Shop',
#  'ESG Edelmetalle',
#  'Kleiner Münzhandel',
#  'Kaiserreich 1 Marksilber-werte.de',
#  'Kleiner Münzhandel',
#  'Leihhaus Lohmann',
#  'Kober Edelmetalle',
#  'Leihhaus Lohmann',
#  'Silverbroker.de',
#  "Euro Gedenkmünzen 10 € bis '10muenzdiscount.de",
#  'Leihhaus Lohmann',
#  'ESG Edelmetalle',
#  'Kaiserreich 5 Marksilber-werte.de',
#  'Anlagegold24.de',
#  'Münzland',
#  'ESG Edelmetalle',
#  'Silverbroker.de',
#  'Silverbroker.de',
#  'silber-werte.de',
#  'Aschhoff Edelmetalle',
#  'GÖBEL Münzen & Edelmetalle',
#  'Münzland',
#  'GoldSilberShop.de',
#  'Faller Edelmetalle',
#  'ESG Edelmetalle',
#  'Münzland',
#  'Münzland',
#  'GÖBEL Münzen & Edelmetalle',
#  'Gold-Silber-Muenzen-Shop',
#  ')Silverbroker.de',
#  'Silber-Corner.de',
#  'Münzen Müller',
#  'Faller Edelmetalle',
#  'Silverbroker.de',
#  'muenzdiscount.de',
#  'Leihhaus Lohmann',
#  'Kronwitter GbR',
#  'Silber-Corner.de',
#  'Münzen Engel',
#  'Anlagegold24.de',
#  'Heubach Edelmetalle',
#  'Kober Edelmetalle',
#  'Kaiserreich 1/2 MarkMünzen Müller',
#  'Kaiserreich 2 MarkHeubach Edelmetalle',
#  'Kober Edelmetalle',
#  'Kronwitter GbR',
#  'ESG Edelmetalle',
#  'Silverbroker.de',
#  'Argentu.de',
#  'Münzland',
#  'Kober Edelmetalle',
#  'Chiemgauer Edelmetallhandel',
#  'Münzland',
#  "Euro Gedenkmünzen 10 € ab '11Leihhaus Lohmann",
#  'Leihhaus Lohmann',
#  'Goldvorsorge.at',
#  'Kleiner Münzhandel',
#  'Leihhaus Lohmann',
#  'GoldSilberShop.de',
#  'Goldvorsorge.at',
#  'Euro Gedenkmünzen 20 €Anlagegold24.de',
#  'Leihhaus Lohmann',
#  'Kronwitter GbR',
#  'Goldvorsorge.at',
#  'Silverbroker.de',
#  'ESG Edelmetalle',
#  'silber-werte.de',
#  'Münzen Müller',
#  'muenzdiscount.de',
#  'Gold-Silber-Muenzen-Shop',
#  'Kleiner Münzhandel',
#  'pro aurum',
#  'philoro Edelmetalle',
#  'muenzdiscount.de',
#  'Faller Edelmetalle',
#  'Münzen Müller',
#  'Gold-Silber-Muenzen-Shop',
#  ')Kober Edelmetalle',
#  'GÖBEL Münzen & Edelmetalle',
#  'Gold-Silber-Muenzen-Shop',
#  'Leihhaus Lohmann',
#  'muenzdiscount.de',
#  'Leihhaus Lohmann',
#  'Gold-Silber-Muenzen-Shop',
#  'muenzdiscount.de',
#  'silber-werte.de',
#  'Münzland',
#  'Faller Edelmetalle',
#  'silber-werte.de',
#  'Faller Edelmetalle',
#  'GÖBEL Münzen & Edelmetalle',
#  'Leihhaus Lohmann',
#  'Anlagegold24.de',
#  'Kober Edelmetalle',
#  'Agosi',
#  'Anlagegold24.de',
#  'ESG Edelmetalle',
#  'Anlagegold24.de',
#  'Anlagegold24.de',
#  'Anlagegold24.de',
#  'Silber-Corner.de',
#  ')Degussa Sonne/Mond Goldhandel',
#  'Gold-Silber-Muenzen-Shop',
#  'Silber-Corner.de',
#  'Faller Edelmetalle',
#  'Leihhaus Lohmann',
#  '25 Euro Deutsche Einheit 25 €Leihhaus Lohmann',
#  'Kober Edelmetalle',
#  ')Heubach Edelmetalle',
#  'Silber-Corner.de',
#  'Faller Edelmetalle',
#  'Münzland',
#  'muenzdiscount.de',
#  'Kettner Edelmetalle',
#  'Bellmann Münzen',
#  'Kleiner Münzhandel',
#  'Anlagegold24.de',
#  'Faller Edelmetalle',
#  'Auragentum.de',
#  'muenzdiscount.de',
#  'Geiger Edelmetalle',
#  'Münzland',
#  'muenzdiscount.de']
